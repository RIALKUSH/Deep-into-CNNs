# %% [markdown]
# # Diabetes Prediction Using Logistic Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv("diabetes2.csv", header=None, skiprows=[0], names=col_names)

# %%
data
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0           6      148  72    35        0  33.6     0.627   50      1
# 1           1       85  66    29        0  26.6     0.351   31      0
# 2           8      183  64     0        0  23.3     0.672   32      1
# 3           1       89  66    23       94  28.1     0.167   21      0
# 4           0      137  40    35      168  43.1     2.288   33      1
# ..        ...      ...  ..   ...      ...   ...       ...  ...    ...
# 763        10      101  76    48      180  32.9     0.171   63      0
# 764         2      122  70    27        0  36.8     0.340   27      0
# 765         5      121  72    23      112  26.2     0.245   30      0
# 766         1      126  60     0        0  30.1     0.349   47      1
# 767         1       93  70    31        0  30.4     0.315   23      0
#
# [768 rows x 9 columns]

# %%
y = data.label.values
x_data = data.drop(["label"],axis=1)

# %%
x_data
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age
# 0           6      148  72    35        0  33.6     0.627   50
# 1           1       85  66    29        0  26.6     0.351   31
# 2           8      183  64     0        0  23.3     0.672   32
# 3           1       89  66    23       94  28.1     0.167   21
# 4           0      137  40    35      168  43.1     2.288   33
# ..        ...      ...  ..   ...      ...   ...       ...  ...
# 763        10      101  76    48      180  32.9     0.171   63
# 764         2      122  70    27        0  36.8     0.340   27
# 765         5      121  72    23      112  26.2     0.245   30
# 766         1      126  60     0        0  30.1     0.349   47
# 767         1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]

# %% [markdown]
# ## Normalization

# %%
x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data)).values

# %%
x
# Out:
#      pregnant   glucose        bp      skin   insulin       bmi  pedigree  \
# 0    0.352941  0.743719  0.590164  0.353535  0.000000  0.500745  0.234415
# 1    0.058824  0.427136  0.540984  0.292929  0.000000  0.396423  0.116567
# 2    0.470588  0.919598  0.524590  0.000000  0.000000  0.347243  0.253629
# 3    0.058824  0.447236  0.540984  0.232323  0.111111  0.418778  0.038002
# 4    0.000000  0.688442  0.327869  0.353535  0.198582  0.642325  0.943638
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  0.588235  0.507538  0.622951  0.484848  0.212766  0.490313  0.039710
# 764  0.117647  0.613065  0.573770  0.272727  0.000000  0.548435  0.111870
# 765  0.294118  0.608040  0.590164  0.232323  0.132388  0.390462  0.071307
# 766  0.058824  0.633166  0.491803  0.000000  0.000000  0.448584  0.115713
# 767  0.058824  0.467337  0.573770  0.313131  0.000000  0.453055  0.101196
#
#           age
# 0    0.483333
# 1    0.166667
# 2    0.183333
# 3    0.000000
# 4    0.200000
# ..        ...
# 763  0.700000
# 764  0.100000
# 765  0.150000
# 766  0.433333
# 767  0.033333
#
# [768 rows x 8 columns]

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = None)

x_train = x_train.T
x_test = x_test.T
y_train = y_train.T
y_test = y_test.T

# %% [markdown]
# ## Parameter Initialize and Sigmoid Function

# %%
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w,b

def sigmoid(z):
    y_head = 1 / (1+np.exp(-z))
    return y_head

# %% [markdown]
# ## Forward and Backward Propagation

# %%
def forward_backward_propagation(w,b,x_train,y_head):
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z)
    loss = -y_train*np.log(y_head) - (1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss)) / x_train.shape[1]
    #backward propogation
    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1]
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]
    gradients = {"derivative_weight": derivative_weight,"derivative_bias": derivative_bias}
    return cost,gradients

# %% [markdown]
# ## Prediction

# %%
def predict(w,b,x_test):
    # x_test is a input for forward propagation
    z = sigmoid(np.dot(w.T,x_test)+b)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    for i in range(z.shape[1]):
        if z[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %% [markdown]
# ## Updating (Learning) Parameters

# %%
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    correctness_list = []
    index = []
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        
        dw= gradients["derivative_weight"]
        db= gradients["derivative_bias"]
        
        # lets update
        w = w - learning_rate * dw
        b = b - learning_rate * db
        
        Y_prediction = predict(w - learning_rate * dw,b - learning_rate * db,x_train)
        correctness = 100 - np.mean(np.abs(Y_prediction - y_train)) * 100
        
        correctness_list.append(correctness)
        cost_list2.append(cost)
        index.append(i)
        print ("Epoch %i: (Cost: %f, Correctness: %f)" %(i+1, cost, correctness))
        
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    
    plt.plot(index,cost_list2)
    plt.xlabel("Epochs")
    plt.ylabel("Cost")
    plt.title("Cost after each Epoch")
    plt.show()
    
    plt.plot(index,correctness_list)
    plt.xlabel("Epochs")
    plt.ylabel("Correctness")
    plt.title("Correctness after each Epoch")
    plt.show()
    return parameters, gradients, cost_list

# %% [markdown]
# ## Defining Logistic Regression Function

# %%
def logistic_regression(x_train, y_train, x_test, y_test, learning_rate ,  num_iterations):
    dimension =  x_train.shape[0]
    w,b = initialize_weights_and_bias(dimension)
    
    parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate,num_iterations)
    
    y_prediction_test = predict(parameters["weight"],parameters["bias"],x_test)
    
    print("test accuracy(Correct/Total): {}/{}".format(y_test.shape[0]-np.sum(np.abs(y_prediction_test - y_test)),(y_test.shape[0])))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.01, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695846, Correctness: 34.690554)
# Epoch 2: (Cost: 0.695434, Correctness: 34.690554)
# Epoch 3: (Cost: 0.695025, Correctness: 35.179153)
# Epoch 4: (Cost: 0.694621, Correctness: 35.830619)
# Epoch 5: (Cost: 0.694221, Correctness: 37.133550)
# Epoch 6: (Cost: 0.693825, Correctness: 43.811075)
# Epoch 7: (Cost: 0.693433, Correctness: 57.166124)
# Epoch 8: (Cost: 0.693045, Correctness: 66.775244)
# Epoch 9: (Cost: 0.692661, Correctness: 70.358306)
# Epoch 10: (Cost: 0.692280, Correctness: 69.218241)
# Epoch 11: (Cost: 0.691904, Correctness: 67.752443)
# Epoch 12: (Cost: 0.691531, Correctness: 66.612378)
# Epoch 13: (Cost: 0.691162, Correctness: 65.309446)
# Epoch 14: (Cost: 0.690797, Correctness: 65.309446)
# Epoch 15: (Cost: 0.690435, Correctness: 65.309446)
# Epoch 16: (Cost: 0.690077, Correctness: 65.309446)
# Epoch 17: (Cost: 0.689722, Correctness: 65.309446)
# Epoch 18: (Cost: 0.689371, Correctness: 65.309446)
# Epoch 19: (Cost: 0.689024, Correctness: 65.309446)
# Epoch 20: (Cost: 0.688679, Correctness: 65.309446)
# Epoch 21: (Cost: 0.688339, Correctness: 65.309446)
# Epoch 22: (Cost: 0.688002, Correctness: 65.309446)
# Epoch 23: (Cost: 0.687668, Correctness: 65.309446)
# Epoch 24: (Cost: 0.687337, Correctness: 65.309446)
# Epoch 25: (Cost: 0.687010, Correctness: 65.309446)
# Epoch 26: (Cost: 0.686686, Correctness: 65.309446)
# Epoch 27: (Cost: 0.686365, Correctness: 65.309446)
# Epoch 28: (Cost: 0.686047, Correctness: 65.309446)
# Epoch 29: (Cost: 0.685733, Correctness: 65.309446)
# Epoch 30: (Cost: 0.685422, Correctness: 65.309446)
# Epoch 31: (Cost: 0.685113, Correctness: 65.309446)
# Epoch 32: (Cost: 0.684808, Correctness: 65.309446)
# Epoch 33: (Cost: 0.684506, Correctness: 65.309446)
# Epoch 34: (Cost: 0.684207, Correctness: 65.309446)
# Epoch 35: (Cost: 0.683910, Correctness: 65.309446)
# Epoch 36: (Cost: 0.683617, Correctness: 65.309446)
# Epoch 37: (Cost: 0.683327, Correctness: 65.309446)
# Epoch 38: (Cost: 0.683039, Correctness: 65.309446)
# Epoch 39: (Cost: 0.682754, Correctness: 65.309446)
# Epoch 40: (Cost: 0.682472, Correctness: 65.309446)
# Epoch 41: (Cost: 0.682193, Correctness: 65.309446)
# Epoch 42: (Cost: 0.681917, Correctness: 65.309446)
# Epoch 43: (Cost: 0.681643, Correctness: 65.309446)
# Epoch 44: (Cost: 0.681372, Correctness: 65.309446)
# Epoch 45: (Cost: 0.681103, Correctness: 65.309446)
# Epoch 46: (Cost: 0.680838, Correctness: 65.309446)
# Epoch 47: (Cost: 0.680574, Correctness: 65.309446)
# Epoch 48: (Cost: 0.680314, Correctness: 65.309446)
# Epoch 49: (Cost: 0.680056, Correctness: 65.309446)
# Epoch 50: (Cost: 0.679800, Correctness: 65.309446)
# Epoch 51: (Cost: 0.679547, Correctness: 65.309446)
# Epoch 52: (Cost: 0.679296, Correctness: 65.309446)
# Epoch 53: (Cost: 0.679048, Correctness: 65.309446)
# Epoch 54: (Cost: 0.678803, Correctness: 65.309446)
# Epoch 55: (Cost: 0.678559, Correctness: 65.309446)
# Epoch 56: (Cost: 0.678318, Correctness: 65.309446)
# Epoch 57: (Cost: 0.678079, Correctness: 65.309446)
# Epoch 58: (Cost: 0.677843, Correctness: 65.309446)
# Epoch 59: (Cost: 0.677609, Correctness: 65.309446)
# Epoch 60: (Cost: 0.677377, Correctness: 65.309446)
# Epoch 61: (Cost: 0.677148, Correctness: 65.309446)
# Epoch 62: (Cost: 0.676920, Correctness: 65.309446)
# Epoch 63: (Cost: 0.676695, Correctness: 65.309446)
# Epoch 64: (Cost: 0.676472, Correctness: 65.309446)
# Epoch 65: (Cost: 0.676251, Correctness: 65.309446)
# Epoch 66: (Cost: 0.676033, Correctness: 65.309446)
# Epoch 67: (Cost: 0.675816, Correctness: 65.309446)
# Epoch 68: (Cost: 0.675601, Correctness: 65.309446)
# Epoch 69: (Cost: 0.675389, Correctness: 65.309446)
# Epoch 70: (Cost: 0.675179, Correctness: 65.309446)
# Epoch 71: (Cost: 0.674970, Correctness: 65.309446)
# Epoch 72: (Cost: 0.674764, Correctness: 65.309446)
# Epoch 73: (Cost: 0.674559, Correctness: 65.309446)
# Epoch 74: (Cost: 0.674357, Correctness: 65.309446)
# Epoch 75: (Cost: 0.674156, Correctness: 65.309446)
# Epoch 76: (Cost: 0.673957, Correctness: 65.309446)
# Epoch 77: (Cost: 0.673761, Correctness: 65.309446)
# Epoch 78: (Cost: 0.673566, Correctness: 65.309446)
# Epoch 79: (Cost: 0.673373, Correctness: 65.309446)
# Epoch 80: (Cost: 0.673181, Correctness: 65.309446)
# Epoch 81: (Cost: 0.672992, Correctness: 65.309446)
# Epoch 82: (Cost: 0.672804, Correctness: 65.309446)
# Epoch 83: (Cost: 0.672618, Correctness: 65.309446)
# Epoch 84: (Cost: 0.672434, Correctness: 65.309446)
# Epoch 85: (Cost: 0.672252, Correctness: 65.309446)
# Epoch 86: (Cost: 0.672071, Correctness: 65.309446)
# Epoch 87: (Cost: 0.671892, Correctness: 65.309446)
# Epoch 88: (Cost: 0.671715, Correctness: 65.309446)
# Epoch 89: (Cost: 0.671539, Correctness: 65.309446)
# Epoch 90: (Cost: 0.671365, Correctness: 65.309446)
# Epoch 91: (Cost: 0.671193, Correctness: 65.309446)
# Epoch 92: (Cost: 0.671022, Correctness: 65.309446)
# Epoch 93: (Cost: 0.670853, Correctness: 65.309446)
# Epoch 94: (Cost: 0.670685, Correctness: 65.309446)
# Epoch 95: (Cost: 0.670519, Correctness: 65.309446)
# Epoch 96: (Cost: 0.670354, Correctness: 65.309446)
# Epoch 97: (Cost: 0.670191, Correctness: 65.309446)
# Epoch 98: (Cost: 0.670030, Correctness: 65.309446)
# Epoch 99: (Cost: 0.669870, Correctness: 65.309446)
# Epoch 100: (Cost: 0.669712, Correctness: 65.309446)
# Epoch 101: (Cost: 0.669554, Correctness: 65.309446)
# Epoch 102: (Cost: 0.669399, Correctness: 65.309446)
# Epoch 103: (Cost: 0.669245, Correctness: 65.309446)
# Epoch 104: (Cost: 0.669092, Correctness: 65.309446)
# Epoch 105: (Cost: 0.668941, Correctness: 65.309446)
# Epoch 106: (Cost: 0.668791, Correctness: 65.309446)
# Epoch 107: (Cost: 0.668642, Correctness: 65.309446)
# Epoch 108: (Cost: 0.668495, Correctness: 65.309446)
# Epoch 109: (Cost: 0.668349, Correctness: 65.309446)
# Epoch 110: (Cost: 0.668204, Correctness: 65.309446)
# Epoch 111: (Cost: 0.668061, Correctness: 65.309446)
# Epoch 112: (Cost: 0.667919, Correctness: 65.309446)
# Epoch 113: (Cost: 0.667779, Correctness: 65.309446)
# Epoch 114: (Cost: 0.667639, Correctness: 65.309446)
# Epoch 115: (Cost: 0.667501, Correctness: 65.309446)
# Epoch 116: (Cost: 0.667364, Correctness: 65.309446)
# Epoch 117: (Cost: 0.667229, Correctness: 65.309446)
# Epoch 118: (Cost: 0.667094, Correctness: 65.309446)
# Epoch 119: (Cost: 0.666961, Correctness: 65.309446)
# Epoch 120: (Cost: 0.666829, Correctness: 65.309446)
# Epoch 121: (Cost: 0.666698, Correctness: 65.309446)
# Epoch 122: (Cost: 0.666568, Correctness: 65.309446)
# Epoch 123: (Cost: 0.666440, Correctness: 65.309446)
# Epoch 124: (Cost: 0.666312, Correctness: 65.309446)
# Epoch 125: (Cost: 0.666186, Correctness: 65.309446)
# Epoch 126: (Cost: 0.666061, Correctness: 65.309446)
# Epoch 127: (Cost: 0.665937, Correctness: 65.309446)
# Epoch 128: (Cost: 0.665814, Correctness: 65.309446)
# Epoch 129: (Cost: 0.665692, Correctness: 65.309446)
# Epoch 130: (Cost: 0.665572, Correctness: 65.309446)
# Epoch 131: (Cost: 0.665452, Correctness: 65.309446)
# Epoch 132: (Cost: 0.665333, Correctness: 65.309446)
# Epoch 133: (Cost: 0.665216, Correctness: 65.309446)
# Epoch 134: (Cost: 0.665099, Correctness: 65.309446)
# Epoch 135: (Cost: 0.664984, Correctness: 65.309446)
# Epoch 136: (Cost: 0.664869, Correctness: 65.309446)
# Epoch 137: (Cost: 0.664756, Correctness: 65.309446)
# Epoch 138: (Cost: 0.664643, Correctness: 65.309446)
# Epoch 139: (Cost: 0.664532, Correctness: 65.309446)
# Epoch 140: (Cost: 0.664421, Correctness: 65.309446)
# Epoch 141: (Cost: 0.664311, Correctness: 65.309446)
# Epoch 142: (Cost: 0.664203, Correctness: 65.309446)
# Epoch 143: (Cost: 0.664095, Correctness: 65.309446)
# Epoch 144: (Cost: 0.663988, Correctness: 65.309446)
# Epoch 145: (Cost: 0.663882, Correctness: 65.309446)
# Epoch 146: (Cost: 0.663777, Correctness: 65.309446)
# Epoch 147: (Cost: 0.663673, Correctness: 65.309446)
# Epoch 148: (Cost: 0.663570, Correctness: 65.309446)
# Epoch 149: (Cost: 0.663467, Correctness: 65.309446)
# Epoch 150: (Cost: 0.663366, Correctness: 65.309446)
# Epoch 151: (Cost: 0.663265, Correctness: 65.309446)
# Epoch 152: (Cost: 0.663166, Correctness: 65.309446)
# Epoch 153: (Cost: 0.663067, Correctness: 65.309446)
# Epoch 154: (Cost: 0.662969, Correctness: 65.309446)
# Epoch 155: (Cost: 0.662871, Correctness: 65.309446)
# Epoch 156: (Cost: 0.662775, Correctness: 65.309446)
# Epoch 157: (Cost: 0.662679, Correctness: 65.309446)
# Epoch 158: (Cost: 0.662585, Correctness: 65.309446)
# Epoch 159: (Cost: 0.662490, Correctness: 65.309446)
# Epoch 160: (Cost: 0.662397, Correctness: 65.309446)
# Epoch 161: (Cost: 0.662305, Correctness: 65.309446)
# Epoch 162: (Cost: 0.662213, Correctness: 65.309446)
# Epoch 163: (Cost: 0.662122, Correctness: 65.309446)
# Epoch 164: (Cost: 0.662032, Correctness: 65.309446)
# Epoch 165: (Cost: 0.661942, Correctness: 65.309446)
# Epoch 166: (Cost: 0.661854, Correctness: 65.309446)
# Epoch 167: (Cost: 0.661766, Correctness: 65.309446)
# Epoch 168: (Cost: 0.661678, Correctness: 65.309446)
# Epoch 169: (Cost: 0.661592, Correctness: 65.309446)
# Epoch 170: (Cost: 0.661506, Correctness: 65.309446)
# Epoch 171: (Cost: 0.661421, Correctness: 65.309446)
# Epoch 172: (Cost: 0.661336, Correctness: 65.309446)
# Epoch 173: (Cost: 0.661253, Correctness: 65.309446)
# Epoch 174: (Cost: 0.661170, Correctness: 65.309446)
# Epoch 175: (Cost: 0.661087, Correctness: 65.309446)
# Epoch 176: (Cost: 0.661005, Correctness: 65.309446)
# Epoch 177: (Cost: 0.660924, Correctness: 65.309446)
# Epoch 178: (Cost: 0.660844, Correctness: 65.309446)
# Epoch 179: (Cost: 0.660764, Correctness: 65.309446)
# Epoch 180: (Cost: 0.660685, Correctness: 65.309446)
# Epoch 181: (Cost: 0.660606, Correctness: 65.309446)
# Epoch 182: (Cost: 0.660528, Correctness: 65.309446)
# Epoch 183: (Cost: 0.660451, Correctness: 65.309446)
# Epoch 184: (Cost: 0.660374, Correctness: 65.309446)
# Epoch 185: (Cost: 0.660298, Correctness: 65.309446)
# Epoch 186: (Cost: 0.660223, Correctness: 65.309446)
# Epoch 187: (Cost: 0.660148, Correctness: 65.309446)
# Epoch 188: (Cost: 0.660073, Correctness: 65.309446)
# Epoch 189: (Cost: 0.660000, Correctness: 65.309446)
# Epoch 190: (Cost: 0.659926, Correctness: 65.309446)
# Epoch 191: (Cost: 0.659854, Correctness: 65.309446)
# Epoch 192: (Cost: 0.659782, Correctness: 65.309446)
# Epoch 193: (Cost: 0.659710, Correctness: 65.309446)
# Epoch 194: (Cost: 0.659639, Correctness: 65.309446)
# Epoch 195: (Cost: 0.659569, Correctness: 65.309446)
# Epoch 196: (Cost: 0.659499, Correctness: 65.309446)
# Epoch 197: (Cost: 0.659430, Correctness: 65.309446)
# Epoch 198: (Cost: 0.659361, Correctness: 65.309446)
# Epoch 199: (Cost: 0.659292, Correctness: 65.309446)
# Epoch 200: (Cost: 0.659225, Correctness: 65.309446)
# test accuracy(Correct/Total): 99.0/154
# test accuracy: 64.28571428571428 %

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.5, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695846, Correctness: 65.309446)
# Epoch 2: (Cost: 0.677780, Correctness: 65.309446)
# Epoch 3: (Cost: 0.667553, Correctness: 65.309446)
# Epoch 4: (Cost: 0.661556, Correctness: 65.309446)
# Epoch 5: (Cost: 0.657851, Correctness: 65.309446)
# Epoch 6: (Cost: 0.655398, Correctness: 65.309446)
# Epoch 7: (Cost: 0.653636, Correctness: 65.309446)
# Epoch 8: (Cost: 0.652260, Correctness: 65.309446)
# Epoch 9: (Cost: 0.651101, Correctness: 65.309446)
# Epoch 10: (Cost: 0.650067, Correctness: 65.309446)
# Epoch 11: (Cost: 0.649107, Correctness: 65.309446)
# Epoch 12: (Cost: 0.648190, Correctness: 65.309446)
# Epoch 13: (Cost: 0.647301, Correctness: 65.309446)
# Epoch 14: (Cost: 0.646431, Correctness: 65.309446)
# Epoch 15: (Cost: 0.645574, Correctness: 65.309446)
# Epoch 16: (Cost: 0.644728, Correctness: 65.309446)
# Epoch 17: (Cost: 0.643890, Correctness: 65.309446)
# Epoch 18: (Cost: 0.643060, Correctness: 65.309446)
# Epoch 19: (Cost: 0.642237, Correctness: 65.309446)
# Epoch 20: (Cost: 0.641421, Correctness: 65.309446)
# Epoch 21: (Cost: 0.640611, Correctness: 65.309446)
# Epoch 22: (Cost: 0.639808, Correctness: 65.309446)
# Epoch 23: (Cost: 0.639010, Correctness: 65.309446)
# Epoch 24: (Cost: 0.638219, Correctness: 65.309446)
# Epoch 25: (Cost: 0.637434, Correctness: 65.309446)
# Epoch 26: (Cost: 0.636655, Correctness: 65.309446)
# Epoch 27: (Cost: 0.635882, Correctness: 65.309446)
# Epoch 28: (Cost: 0.635115, Correctness: 65.309446)
# Epoch 29: (Cost: 0.634353, Correctness: 65.309446)
# Epoch 30: (Cost: 0.633597, Correctness: 65.309446)
# Epoch 31: (Cost: 0.632847, Correctness: 65.309446)
# Epoch 32: (Cost: 0.632102, Correctness: 65.309446)
# Epoch 33: (Cost: 0.631364, Correctness: 65.309446)
# Epoch 34: (Cost: 0.630630, Correctness: 65.309446)
# Epoch 35: (Cost: 0.629902, Correctness: 65.309446)
# Epoch 36: (Cost: 0.629179, Correctness: 65.309446)
# Epoch 37: (Cost: 0.628462, Correctness: 65.309446)
# Epoch 38: (Cost: 0.627750, Correctness: 65.309446)
# Epoch 39: (Cost: 0.627043, Correctness: 65.309446)
# Epoch 40: (Cost: 0.626342, Correctness: 65.309446)
# Epoch 41: (Cost: 0.625646, Correctness: 65.309446)
# Epoch 42: (Cost: 0.624954, Correctness: 65.309446)
# Epoch 43: (Cost: 0.624268, Correctness: 65.309446)
# Epoch 44: (Cost: 0.623587, Correctness: 65.309446)
# Epoch 45: (Cost: 0.622911, Correctness: 65.309446)
# Epoch 46: (Cost: 0.622239, Correctness: 65.309446)
# Epoch 47: (Cost: 0.621573, Correctness: 65.309446)
# Epoch 48: (Cost: 0.620911, Correctness: 65.309446)
# Epoch 49: (Cost: 0.620254, Correctness: 65.309446)
# Epoch 50: (Cost: 0.619602, Correctness: 65.309446)
# Epoch 51: (Cost: 0.618954, Correctness: 65.309446)
# Epoch 52: (Cost: 0.618311, Correctness: 65.309446)
# Epoch 53: (Cost: 0.617673, Correctness: 65.309446)
# Epoch 54: (Cost: 0.617039, Correctness: 65.309446)
# Epoch 55: (Cost: 0.616410, Correctness: 65.309446)
# Epoch 56: (Cost: 0.615785, Correctness: 65.309446)
# Epoch 57: (Cost: 0.615164, Correctness: 65.309446)
# Epoch 58: (Cost: 0.614548, Correctness: 65.309446)
# Epoch 59: (Cost: 0.613937, Correctness: 65.309446)
# Epoch 60: (Cost: 0.613329, Correctness: 65.309446)
# Epoch 61: (Cost: 0.612726, Correctness: 65.309446)
# Epoch 62: (Cost: 0.612127, Correctness: 65.309446)
# Epoch 63: (Cost: 0.611532, Correctness: 65.472313)
# Epoch 64: (Cost: 0.610941, Correctness: 65.472313)
# Epoch 65: (Cost: 0.610354, Correctness: 65.635179)
# Epoch 66: (Cost: 0.609772, Correctness: 65.635179)
# Epoch 67: (Cost: 0.609193, Correctness: 65.635179)
# Epoch 68: (Cost: 0.608618, Correctness: 65.635179)
# Epoch 69: (Cost: 0.608047, Correctness: 65.798046)
# Epoch 70: (Cost: 0.607481, Correctness: 65.960912)
# Epoch 71: (Cost: 0.606918, Correctness: 65.960912)
# Epoch 72: (Cost: 0.606358, Correctness: 65.960912)
# Epoch 73: (Cost: 0.605803, Correctness: 65.960912)
# Epoch 74: (Cost: 0.605251, Correctness: 65.798046)
# Epoch 75: (Cost: 0.604703, Correctness: 65.960912)
# Epoch 76: (Cost: 0.604159, Correctness: 65.798046)
# Epoch 77: (Cost: 0.603618, Correctness: 65.960912)
# Epoch 78: (Cost: 0.603081, Correctness: 66.123779)
# Epoch 79: (Cost: 0.602548, Correctness: 66.123779)
# Epoch 80: (Cost: 0.602018, Correctness: 66.123779)
# Epoch 81: (Cost: 0.601492, Correctness: 66.123779)
# Epoch 82: (Cost: 0.600969, Correctness: 66.286645)
# Epoch 83: (Cost: 0.600449, Correctness: 66.286645)
# Epoch 84: (Cost: 0.599933, Correctness: 66.286645)
# Epoch 85: (Cost: 0.599420, Correctness: 66.286645)
# Epoch 86: (Cost: 0.598911, Correctness: 66.286645)
# Epoch 87: (Cost: 0.598405, Correctness: 66.286645)
# Epoch 88: (Cost: 0.597902, Correctness: 66.449511)
# Epoch 89: (Cost: 0.597403, Correctness: 66.612378)
# Epoch 90: (Cost: 0.596907, Correctness: 66.775244)
# Epoch 91: (Cost: 0.596414, Correctness: 66.612378)
# Epoch 92: (Cost: 0.595924, Correctness: 66.775244)
# Epoch 93: (Cost: 0.595437, Correctness: 66.775244)
# Epoch 94: (Cost: 0.594953, Correctness: 66.775244)
# Epoch 95: (Cost: 0.594473, Correctness: 67.100977)
# Epoch 96: (Cost: 0.593995, Correctness: 67.263844)
# Epoch 97: (Cost: 0.593521, Correctness: 67.263844)
# Epoch 98: (Cost: 0.593049, Correctness: 67.100977)
# Epoch 99: (Cost: 0.592581, Correctness: 67.100977)
# Epoch 100: (Cost: 0.592115, Correctness: 67.100977)
# Epoch 101: (Cost: 0.591653, Correctness: 67.263844)
# Epoch 102: (Cost: 0.591193, Correctness: 67.263844)
# Epoch 103: (Cost: 0.590736, Correctness: 67.263844)
# Epoch 104: (Cost: 0.590282, Correctness: 67.263844)
# Epoch 105: (Cost: 0.589831, Correctness: 67.263844)
# Epoch 106: (Cost: 0.589383, Correctness: 67.263844)
# Epoch 107: (Cost: 0.588937, Correctness: 67.263844)
# Epoch 108: (Cost: 0.588494, Correctness: 67.100977)
# Epoch 109: (Cost: 0.588054, Correctness: 67.100977)
# Epoch 110: (Cost: 0.587616, Correctness: 66.938111)
# Epoch 111: (Cost: 0.587182, Correctness: 67.100977)
# Epoch 112: (Cost: 0.586749, Correctness: 67.100977)
# Epoch 113: (Cost: 0.586320, Correctness: 67.100977)
# Epoch 114: (Cost: 0.585893, Correctness: 67.100977)
# Epoch 115: (Cost: 0.585469, Correctness: 67.263844)
# Epoch 116: (Cost: 0.585047, Correctness: 67.426710)
# Epoch 117: (Cost: 0.584628, Correctness: 67.589577)
# Epoch 118: (Cost: 0.584211, Correctness: 67.589577)
# Epoch 119: (Cost: 0.583797, Correctness: 67.752443)
# Epoch 120: (Cost: 0.583385, Correctness: 67.752443)
# Epoch 121: (Cost: 0.582975, Correctness: 67.915309)
# Epoch 122: (Cost: 0.582569, Correctness: 68.078176)
# Epoch 123: (Cost: 0.582164, Correctness: 68.241042)
# Epoch 124: (Cost: 0.581762, Correctness: 68.241042)
# Epoch 125: (Cost: 0.581362, Correctness: 68.078176)
# Epoch 126: (Cost: 0.580965, Correctness: 68.078176)
# Epoch 127: (Cost: 0.580570, Correctness: 68.566775)
# Epoch 128: (Cost: 0.580177, Correctness: 68.729642)
# Epoch 129: (Cost: 0.579786, Correctness: 68.892508)
# Epoch 130: (Cost: 0.579398, Correctness: 68.892508)
# Epoch 131: (Cost: 0.579012, Correctness: 69.055375)
# Epoch 132: (Cost: 0.578628, Correctness: 69.218241)
# Epoch 133: (Cost: 0.578247, Correctness: 69.381107)
# Epoch 134: (Cost: 0.577867, Correctness: 69.381107)
# Epoch 135: (Cost: 0.577490, Correctness: 69.381107)
# Epoch 136: (Cost: 0.577115, Correctness: 69.381107)
# Epoch 137: (Cost: 0.576742, Correctness: 69.543974)
# Epoch 138: (Cost: 0.576371, Correctness: 69.543974)
# Epoch 139: (Cost: 0.576003, Correctness: 69.543974)
# Epoch 140: (Cost: 0.575636, Correctness: 69.543974)
# Epoch 141: (Cost: 0.575272, Correctness: 69.381107)
# Epoch 142: (Cost: 0.574909, Correctness: 69.381107)
# Epoch 143: (Cost: 0.574549, Correctness: 69.381107)
# Epoch 144: (Cost: 0.574190, Correctness: 69.543974)
# Epoch 145: (Cost: 0.573834, Correctness: 69.543974)
# Epoch 146: (Cost: 0.573479, Correctness: 69.706840)
# Epoch 147: (Cost: 0.573127, Correctness: 70.032573)
# Epoch 148: (Cost: 0.572776, Correctness: 70.032573)
# Epoch 149: (Cost: 0.572427, Correctness: 70.032573)
# Epoch 150: (Cost: 0.572081, Correctness: 70.358306)
# Epoch 151: (Cost: 0.571736, Correctness: 70.358306)
# Epoch 152: (Cost: 0.571393, Correctness: 70.358306)
# Epoch 153: (Cost: 0.571052, Correctness: 70.521173)
# Epoch 154: (Cost: 0.570713, Correctness: 70.358306)
# Epoch 155: (Cost: 0.570375, Correctness: 70.358306)
# Epoch 156: (Cost: 0.570040, Correctness: 70.521173)
# Epoch 157: (Cost: 0.569706, Correctness: 70.521173)
# Epoch 158: (Cost: 0.569374, Correctness: 70.521173)
# Epoch 159: (Cost: 0.569044, Correctness: 70.358306)
# Epoch 160: (Cost: 0.568716, Correctness: 70.358306)
# Epoch 161: (Cost: 0.568389, Correctness: 70.358306)
# Epoch 162: (Cost: 0.568064, Correctness: 70.358306)
# Epoch 163: (Cost: 0.567741, Correctness: 70.521173)
# Epoch 164: (Cost: 0.567420, Correctness: 70.195440)
# Epoch 165: (Cost: 0.567100, Correctness: 70.358306)
# Epoch 166: (Cost: 0.566782, Correctness: 70.358306)
# Epoch 167: (Cost: 0.566466, Correctness: 70.358306)
# Epoch 168: (Cost: 0.566151, Correctness: 70.358306)
# Epoch 169: (Cost: 0.565838, Correctness: 70.358306)
# Epoch 170: (Cost: 0.565527, Correctness: 70.358306)
# Epoch 171: (Cost: 0.565217, Correctness: 70.684039)
# Epoch 172: (Cost: 0.564909, Correctness: 71.009772)
# Epoch 173: (Cost: 0.564602, Correctness: 71.172638)
# Epoch 174: (Cost: 0.564297, Correctness: 71.172638)
# Epoch 175: (Cost: 0.563994, Correctness: 71.172638)
# Epoch 176: (Cost: 0.563692, Correctness: 71.172638)
# Epoch 177: (Cost: 0.563392, Correctness: 71.335505)
# Epoch 178: (Cost: 0.563093, Correctness: 71.335505)
# Epoch 179: (Cost: 0.562796, Correctness: 71.335505)
# Epoch 180: (Cost: 0.562500, Correctness: 71.498371)
# Epoch 181: (Cost: 0.562206, Correctness: 71.498371)
# Epoch 182: (Cost: 0.561913, Correctness: 71.661238)
# Epoch 183: (Cost: 0.561622, Correctness: 71.498371)
# Epoch 184: (Cost: 0.561332, Correctness: 71.498371)
# Epoch 185: (Cost: 0.561044, Correctness: 71.498371)
# Epoch 186: (Cost: 0.560757, Correctness: 71.498371)
# Epoch 187: (Cost: 0.560472, Correctness: 71.498371)
# Epoch 188: (Cost: 0.560188, Correctness: 71.661238)
# Epoch 189: (Cost: 0.559905, Correctness: 71.498371)
# Epoch 190: (Cost: 0.559624, Correctness: 71.498371)
# Epoch 191: (Cost: 0.559344, Correctness: 71.661238)
# Epoch 192: (Cost: 0.559066, Correctness: 71.986971)
# Epoch 193: (Cost: 0.558789, Correctness: 71.986971)
# Epoch 194: (Cost: 0.558513, Correctness: 71.986971)
# Epoch 195: (Cost: 0.558239, Correctness: 71.986971)
# Epoch 196: (Cost: 0.557966, Correctness: 72.312704)
# Epoch 197: (Cost: 0.557695, Correctness: 72.475570)
# Epoch 198: (Cost: 0.557424, Correctness: 72.475570)
# Epoch 199: (Cost: 0.557155, Correctness: 72.475570)
# Epoch 200: (Cost: 0.556888, Correctness: 72.475570)
# test accuracy(Correct/Total): 107.0/154
# test accuracy: 69.48051948051949 %

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 2, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695846, Correctness: 65.309446)
# Epoch 2: (Cost: 0.654363, Correctness: 65.309446)
# Epoch 3: (Cost: 0.650709, Correctness: 65.309446)
# Epoch 4: (Cost: 0.647204, Correctness: 65.309446)
# Epoch 5: (Cost: 0.643809, Correctness: 65.309446)
# Epoch 6: (Cost: 0.640517, Correctness: 65.309446)
# Epoch 7: (Cost: 0.637326, Correctness: 65.309446)
# Epoch 8: (Cost: 0.634232, Correctness: 65.309446)
# Epoch 9: (Cost: 0.631230, Correctness: 65.309446)
# Epoch 10: (Cost: 0.628318, Correctness: 65.309446)
# Epoch 11: (Cost: 0.625491, Correctness: 65.309446)
# Epoch 12: (Cost: 0.622747, Correctness: 65.309446)
# Epoch 13: (Cost: 0.620082, Correctness: 65.309446)
# Epoch 14: (Cost: 0.617494, Correctness: 65.309446)
# Epoch 15: (Cost: 0.614978, Correctness: 65.472313)
# Epoch 16: (Cost: 0.612534, Correctness: 65.635179)
# Epoch 17: (Cost: 0.610157, Correctness: 65.960912)
# Epoch 18: (Cost: 0.607845, Correctness: 65.960912)
# Epoch 19: (Cost: 0.605596, Correctness: 66.123779)
# Epoch 20: (Cost: 0.603408, Correctness: 66.286645)
# Epoch 21: (Cost: 0.601278, Correctness: 66.449511)
# Epoch 22: (Cost: 0.599204, Correctness: 66.775244)
# Epoch 23: (Cost: 0.597184, Correctness: 67.100977)
# Epoch 24: (Cost: 0.595216, Correctness: 67.100977)
# Epoch 25: (Cost: 0.593298, Correctness: 67.263844)
# Epoch 26: (Cost: 0.591428, Correctness: 67.100977)
# Epoch 27: (Cost: 0.589605, Correctness: 67.100977)
# Epoch 28: (Cost: 0.587827, Correctness: 67.426710)
# Epoch 29: (Cost: 0.586093, Correctness: 67.915309)
# Epoch 30: (Cost: 0.584400, Correctness: 68.241042)
# Epoch 31: (Cost: 0.582747, Correctness: 68.729642)
# Epoch 32: (Cost: 0.581134, Correctness: 69.055375)
# Epoch 33: (Cost: 0.579558, Correctness: 69.381107)
# Epoch 34: (Cost: 0.578019, Correctness: 69.381107)
# Epoch 35: (Cost: 0.576514, Correctness: 69.543974)
# Epoch 36: (Cost: 0.575044, Correctness: 70.032573)
# Epoch 37: (Cost: 0.573607, Correctness: 70.358306)
# Epoch 38: (Cost: 0.572202, Correctness: 70.521173)
# Epoch 39: (Cost: 0.570827, Correctness: 70.358306)
# Epoch 40: (Cost: 0.569482, Correctness: 70.195440)
# Epoch 41: (Cost: 0.568166, Correctness: 70.358306)
# Epoch 42: (Cost: 0.566878, Correctness: 70.846906)
# Epoch 43: (Cost: 0.565617, Correctness: 71.335505)
# Epoch 44: (Cost: 0.564382, Correctness: 71.498371)
# Epoch 45: (Cost: 0.563173, Correctness: 71.498371)
# Epoch 46: (Cost: 0.561988, Correctness: 71.498371)
# Epoch 47: (Cost: 0.560828, Correctness: 71.986971)
# Epoch 48: (Cost: 0.559690, Correctness: 72.312704)
# Epoch 49: (Cost: 0.558575, Correctness: 72.475570)
# Epoch 50: (Cost: 0.557482, Correctness: 72.475570)
# Epoch 51: (Cost: 0.556410, Correctness: 72.801303)
# Epoch 52: (Cost: 0.555359, Correctness: 72.801303)
# Epoch 53: (Cost: 0.554328, Correctness: 72.964169)
# Epoch 54: (Cost: 0.553316, Correctness: 72.964169)
# Epoch 55: (Cost: 0.552324, Correctness: 72.964169)
# Epoch 56: (Cost: 0.551349, Correctness: 72.964169)
# Epoch 57: (Cost: 0.550393, Correctness: 72.964169)
# Epoch 58: (Cost: 0.549454, Correctness: 73.127036)
# Epoch 59: (Cost: 0.548532, Correctness: 73.127036)
# Epoch 60: (Cost: 0.547627, Correctness: 73.127036)
# Epoch 61: (Cost: 0.546737, Correctness: 73.289902)
# Epoch 62: (Cost: 0.545864, Correctness: 73.452769)
# Epoch 63: (Cost: 0.545005, Correctness: 73.778502)
# Epoch 64: (Cost: 0.544162, Correctness: 73.778502)
# Epoch 65: (Cost: 0.543332, Correctness: 73.941368)
# Epoch 66: (Cost: 0.542517, Correctness: 73.778502)
# Epoch 67: (Cost: 0.541716, Correctness: 73.778502)
# Epoch 68: (Cost: 0.540928, Correctness: 73.778502)
# Epoch 69: (Cost: 0.540153, Correctness: 73.778502)
# Epoch 70: (Cost: 0.539391, Correctness: 74.104235)
# Epoch 71: (Cost: 0.538642, Correctness: 74.267101)
# Epoch 72: (Cost: 0.537905, Correctness: 74.104235)
# Epoch 73: (Cost: 0.537179, Correctness: 73.941368)
# Epoch 74: (Cost: 0.536465, Correctness: 74.104235)
# Epoch 75: (Cost: 0.535762, Correctness: 74.104235)
# Epoch 76: (Cost: 0.535071, Correctness: 74.104235)
# Epoch 77: (Cost: 0.534390, Correctness: 74.104235)
# Epoch 78: (Cost: 0.533720, Correctness: 74.104235)
# Epoch 79: (Cost: 0.533060, Correctness: 74.429967)
# Epoch 80: (Cost: 0.532410, Correctness: 74.429967)
# Epoch 81: (Cost: 0.531770, Correctness: 74.429967)
# Epoch 82: (Cost: 0.531140, Correctness: 74.267101)
# Epoch 83: (Cost: 0.530519, Correctness: 74.267101)
# Epoch 84: (Cost: 0.529907, Correctness: 74.267101)
# Epoch 85: (Cost: 0.529305, Correctness: 74.267101)
# Epoch 86: (Cost: 0.528711, Correctness: 74.429967)
# Epoch 87: (Cost: 0.528126, Correctness: 74.267101)
# Epoch 88: (Cost: 0.527549, Correctness: 74.104235)
# Epoch 89: (Cost: 0.526980, Correctness: 74.104235)
# Epoch 90: (Cost: 0.526420, Correctness: 74.104235)
# Epoch 91: (Cost: 0.525868, Correctness: 74.104235)
# Epoch 92: (Cost: 0.525323, Correctness: 74.104235)
# Epoch 93: (Cost: 0.524786, Correctness: 74.104235)
# Epoch 94: (Cost: 0.524256, Correctness: 74.104235)
# Epoch 95: (Cost: 0.523734, Correctness: 74.267101)
# Epoch 96: (Cost: 0.523219, Correctness: 74.267101)
# Epoch 97: (Cost: 0.522711, Correctness: 74.267101)
# Epoch 98: (Cost: 0.522210, Correctness: 74.104235)
# Epoch 99: (Cost: 0.521715, Correctness: 74.267101)
# Epoch 100: (Cost: 0.521227, Correctness: 74.429967)
# Epoch 101: (Cost: 0.520746, Correctness: 74.592834)
# Epoch 102: (Cost: 0.520271, Correctness: 74.592834)
# Epoch 103: (Cost: 0.519802, Correctness: 74.755700)
# Epoch 104: (Cost: 0.519339, Correctness: 74.918567)
# Epoch 105: (Cost: 0.518883, Correctness: 75.081433)
# Epoch 106: (Cost: 0.518432, Correctness: 75.081433)
# Epoch 107: (Cost: 0.517987, Correctness: 75.081433)
# Epoch 108: (Cost: 0.517548, Correctness: 75.081433)
# Epoch 109: (Cost: 0.517114, Correctness: 75.081433)
# Epoch 110: (Cost: 0.516686, Correctness: 75.081433)
# Epoch 111: (Cost: 0.516263, Correctness: 75.081433)
# Epoch 112: (Cost: 0.515845, Correctness: 75.081433)
# Epoch 113: (Cost: 0.515433, Correctness: 75.081433)
# Epoch 114: (Cost: 0.515025, Correctness: 75.081433)
# Epoch 115: (Cost: 0.514623, Correctness: 75.244300)
# Epoch 116: (Cost: 0.514226, Correctness: 75.244300)
# Epoch 117: (Cost: 0.513833, Correctness: 75.244300)
# Epoch 118: (Cost: 0.513445, Correctness: 75.407166)
# Epoch 119: (Cost: 0.513062, Correctness: 75.570033)
# Epoch 120: (Cost: 0.512683, Correctness: 75.244300)
# Epoch 121: (Cost: 0.512309, Correctness: 75.244300)
# Epoch 122: (Cost: 0.511939, Correctness: 75.244300)
# Epoch 123: (Cost: 0.511574, Correctness: 75.244300)
# Epoch 124: (Cost: 0.511213, Correctness: 75.244300)
# Epoch 125: (Cost: 0.510856, Correctness: 75.244300)
# Epoch 126: (Cost: 0.510503, Correctness: 75.244300)
# Epoch 127: (Cost: 0.510154, Correctness: 75.244300)
# Epoch 128: (Cost: 0.509809, Correctness: 75.244300)
# Epoch 129: (Cost: 0.509469, Correctness: 75.244300)
# Epoch 130: (Cost: 0.509132, Correctness: 75.081433)
# Epoch 131: (Cost: 0.508799, Correctness: 75.081433)
# Epoch 132: (Cost: 0.508469, Correctness: 75.244300)
# Epoch 133: (Cost: 0.508143, Correctness: 75.244300)
# Epoch 134: (Cost: 0.507821, Correctness: 75.244300)
# Epoch 135: (Cost: 0.507503, Correctness: 75.244300)
# Epoch 136: (Cost: 0.507188, Correctness: 75.407166)
# Epoch 137: (Cost: 0.506876, Correctness: 75.407166)
# Epoch 138: (Cost: 0.506568, Correctness: 75.407166)
# Epoch 139: (Cost: 0.506263, Correctness: 75.407166)
# Epoch 140: (Cost: 0.505962, Correctness: 75.244300)
# Epoch 141: (Cost: 0.505664, Correctness: 75.407166)
# Epoch 142: (Cost: 0.505369, Correctness: 75.407166)
# Epoch 143: (Cost: 0.505077, Correctness: 75.407166)
# Epoch 144: (Cost: 0.504788, Correctness: 75.407166)
# Epoch 145: (Cost: 0.504502, Correctness: 75.407166)
# Epoch 146: (Cost: 0.504219, Correctness: 75.407166)
# Epoch 147: (Cost: 0.503940, Correctness: 75.244300)
# Epoch 148: (Cost: 0.503663, Correctness: 75.244300)
# Epoch 149: (Cost: 0.503389, Correctness: 75.407166)
# Epoch 150: (Cost: 0.503118, Correctness: 75.407166)
# Epoch 151: (Cost: 0.502849, Correctness: 75.407166)
# Epoch 152: (Cost: 0.502584, Correctness: 75.407166)
# Epoch 153: (Cost: 0.502321, Correctness: 75.244300)
# Epoch 154: (Cost: 0.502061, Correctness: 75.244300)
# Epoch 155: (Cost: 0.501803, Correctness: 75.244300)
# Epoch 156: (Cost: 0.501548, Correctness: 75.081433)
# Epoch 157: (Cost: 0.501296, Correctness: 75.081433)
# Epoch 158: (Cost: 0.501046, Correctness: 74.918567)
# Epoch 159: (Cost: 0.500799, Correctness: 74.918567)
# Epoch 160: (Cost: 0.500554, Correctness: 75.081433)
# Epoch 161: (Cost: 0.500311, Correctness: 75.081433)
# Epoch 162: (Cost: 0.500071, Correctness: 75.081433)
# Epoch 163: (Cost: 0.499833, Correctness: 75.081433)
# Epoch 164: (Cost: 0.499598, Correctness: 75.081433)
# Epoch 165: (Cost: 0.499365, Correctness: 75.244300)
# Epoch 166: (Cost: 0.499134, Correctness: 75.244300)
# Epoch 167: (Cost: 0.498905, Correctness: 75.244300)
# Epoch 168: (Cost: 0.498679, Correctness: 75.244300)
# Epoch 169: (Cost: 0.498455, Correctness: 75.244300)
# Epoch 170: (Cost: 0.498233, Correctness: 75.081433)
# Epoch 171: (Cost: 0.498013, Correctness: 75.081433)
# Epoch 172: (Cost: 0.497795, Correctness: 75.081433)
# Epoch 173: (Cost: 0.497579, Correctness: 75.081433)
# Epoch 174: (Cost: 0.497365, Correctness: 75.244300)
# Epoch 175: (Cost: 0.497153, Correctness: 75.244300)
# Epoch 176: (Cost: 0.496943, Correctness: 75.407166)
# Epoch 177: (Cost: 0.496735, Correctness: 75.407166)
# Epoch 178: (Cost: 0.496530, Correctness: 75.407166)
# Epoch 179: (Cost: 0.496325, Correctness: 75.407166)
# Epoch 180: (Cost: 0.496123, Correctness: 75.407166)
# Epoch 181: (Cost: 0.495923, Correctness: 75.407166)
# Epoch 182: (Cost: 0.495724, Correctness: 75.407166)
# Epoch 183: (Cost: 0.495528, Correctness: 75.407166)
# Epoch 184: (Cost: 0.495333, Correctness: 75.407166)
# Epoch 185: (Cost: 0.495140, Correctness: 75.570033)
# Epoch 186: (Cost: 0.494948, Correctness: 75.570033)
# Epoch 187: (Cost: 0.494759, Correctness: 75.732899)
# Epoch 188: (Cost: 0.494571, Correctness: 75.732899)
# Epoch 189: (Cost: 0.494384, Correctness: 75.732899)
# Epoch 190: (Cost: 0.494200, Correctness: 75.570033)
# Epoch 191: (Cost: 0.494017, Correctness: 75.570033)
# Epoch 192: (Cost: 0.493836, Correctness: 75.895765)
# Epoch 193: (Cost: 0.493656, Correctness: 75.732899)
# Epoch 194: (Cost: 0.493478, Correctness: 75.732899)
# Epoch 195: (Cost: 0.493301, Correctness: 75.732899)
# Epoch 196: (Cost: 0.493126, Correctness: 75.732899)
# Epoch 197: (Cost: 0.492952, Correctness: 75.570033)
# Epoch 198: (Cost: 0.492780, Correctness: 75.570033)
# Epoch 199: (Cost: 0.492610, Correctness: 75.570033)
# Epoch 200: (Cost: 0.492441, Correctness: 75.570033)
# test accuracy(Correct/Total): 123.0/154
# test accuracy: 79.87012987012987 %
