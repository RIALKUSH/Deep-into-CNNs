# %% [markdown]
# # Diabetes Prediction Using Logistic Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv("diabetes2.csv", header=None, skiprows=[0], names=col_names)

# %%
data
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0           6      148  72    35        0  33.6     0.627   50      1
# 1           1       85  66    29        0  26.6     0.351   31      0
# 2           8      183  64     0        0  23.3     0.672   32      1
# 3           1       89  66    23       94  28.1     0.167   21      0
# 4           0      137  40    35      168  43.1     2.288   33      1
# ..        ...      ...  ..   ...      ...   ...       ...  ...    ...
# 763        10      101  76    48      180  32.9     0.171   63      0
# 764         2      122  70    27        0  36.8     0.340   27      0
# 765         5      121  72    23      112  26.2     0.245   30      0
# 766         1      126  60     0        0  30.1     0.349   47      1
# 767         1       93  70    31        0  30.4     0.315   23      0
#
# [768 rows x 9 columns]

# %%
y = data.label.values
x_data = data.drop(["label"],axis=1)

# %%
x_data
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age
# 0           6      148  72    35        0  33.6     0.627   50
# 1           1       85  66    29        0  26.6     0.351   31
# 2           8      183  64     0        0  23.3     0.672   32
# 3           1       89  66    23       94  28.1     0.167   21
# 4           0      137  40    35      168  43.1     2.288   33
# ..        ...      ...  ..   ...      ...   ...       ...  ...
# 763        10      101  76    48      180  32.9     0.171   63
# 764         2      122  70    27        0  36.8     0.340   27
# 765         5      121  72    23      112  26.2     0.245   30
# 766         1      126  60     0        0  30.1     0.349   47
# 767         1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]

# %% [markdown]
# ## Normalization

# %%
x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data)).values

# %%
x
# Out:
#      pregnant   glucose        bp      skin   insulin       bmi  pedigree  \
# 0    0.352941  0.743719  0.590164  0.353535  0.000000  0.500745  0.234415
# 1    0.058824  0.427136  0.540984  0.292929  0.000000  0.396423  0.116567
# 2    0.470588  0.919598  0.524590  0.000000  0.000000  0.347243  0.253629
# 3    0.058824  0.447236  0.540984  0.232323  0.111111  0.418778  0.038002
# 4    0.000000  0.688442  0.327869  0.353535  0.198582  0.642325  0.943638
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  0.588235  0.507538  0.622951  0.484848  0.212766  0.490313  0.039710
# 764  0.117647  0.613065  0.573770  0.272727  0.000000  0.548435  0.111870
# 765  0.294118  0.608040  0.590164  0.232323  0.132388  0.390462  0.071307
# 766  0.058824  0.633166  0.491803  0.000000  0.000000  0.448584  0.115713
# 767  0.058824  0.467337  0.573770  0.313131  0.000000  0.453055  0.101196
#
#           age
# 0    0.483333
# 1    0.166667
# 2    0.183333
# 3    0.000000
# 4    0.200000
# ..        ...
# 763  0.700000
# 764  0.100000
# 765  0.150000
# 766  0.433333
# 767  0.033333
#
# [768 rows x 8 columns]

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = None)

x_train = x_train.T
x_test = x_test.T
y_train = y_train.T
y_test = y_test.T

# %% [markdown]
# ## Parameter Initialize and Sigmoid Function

# %%
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w,b

def sigmoid(z):
    y_head = 1 / (1+np.exp(-z))
    return y_head

# %% [markdown]
# ## Forward and Backward Propagation

# %%
def forward_backward_propagation(w,b,x_train,y_head):
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z)
    loss = -y_train*np.log(y_head) - (1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss)) / x_train.shape[1]
    #backward propogation
    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1]
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]
    gradients = {"derivative_weight": derivative_weight,"derivative_bias": derivative_bias}
    return cost,gradients

# %% [markdown]
# ## Prediction

# %%
def predict(w,b,x_test):
    # x_test is a input for forward propagation
    z = sigmoid(np.dot(w.T,x_test)+b)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    for i in range(z.shape[1]):
        if z[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %% [markdown]
# ## Updating (Learning) Parameters

# %%
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    correctness_list = []
    index = []
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        
        dw= gradients["derivative_weight"]
        db= gradients["derivative_bias"]
        
        # lets update
        w = w - learning_rate * dw
        b = b - learning_rate * db
        
        Y_prediction = predict(w - learning_rate * dw,b - learning_rate * db,x_train)
        correctness = 100 - np.mean(np.abs(Y_prediction - y_train)) * 100
        
        correctness_list.append(correctness)
        cost_list2.append(cost)
        index.append(i)
        print ("Epoch %i: (Cost: %f, Correctness: %f)" %(i+1, cost, correctness))
        
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    
    plt.plot(index,cost_list2)
    plt.xlabel("Epochs")
    plt.ylabel("Cost")
    plt.title("Cost after each Epoch")
    plt.show()
    
    plt.plot(index,correctness_list)
    plt.xlabel("Epochs")
    plt.ylabel("Correctness")
    plt.title("Correctness after each Epoch")
    plt.show()
    return parameters, gradients, cost_list

# %% [markdown]
# ## Defining Logistic Regression Function

# %%
def logistic_regression(x_train, y_train, x_test, y_test, learning_rate ,  num_iterations):
    dimension =  x_train.shape[0]
    w,b = initialize_weights_and_bias(dimension)
    
    parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate,num_iterations)
    
    y_prediction_test = predict(parameters["weight"],parameters["bias"],x_test)
    
    print("test accuracy(Correct/Total): {}/{}".format(y_test.shape[0]-np.sum(np.abs(y_prediction_test - y_test)),(y_test.shape[0])))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.01, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695866, Correctness: 34.853420)
# Epoch 2: (Cost: 0.695461, Correctness: 35.016287)
# Epoch 3: (Cost: 0.695060, Correctness: 35.504886)
# Epoch 4: (Cost: 0.694662, Correctness: 35.993485)
# Epoch 5: (Cost: 0.694269, Correctness: 37.133550)
# Epoch 6: (Cost: 0.693880, Correctness: 42.996743)
# Epoch 7: (Cost: 0.693495, Correctness: 56.677524)
# Epoch 8: (Cost: 0.693114, Correctness: 64.495114)
# Epoch 9: (Cost: 0.692736, Correctness: 69.543974)
# Epoch 10: (Cost: 0.692362, Correctness: 69.381107)
# Epoch 11: (Cost: 0.691992, Correctness: 67.426710)
# Epoch 12: (Cost: 0.691626, Correctness: 66.123779)
# Epoch 13: (Cost: 0.691263, Correctness: 64.983713)
# Epoch 14: (Cost: 0.690904, Correctness: 65.146580)
# Epoch 15: (Cost: 0.690549, Correctness: 65.146580)
# Epoch 16: (Cost: 0.690197, Correctness: 65.146580)
# Epoch 17: (Cost: 0.689849, Correctness: 65.146580)
# Epoch 18: (Cost: 0.689504, Correctness: 65.146580)
# Epoch 19: (Cost: 0.689163, Correctness: 65.146580)
# Epoch 20: (Cost: 0.688825, Correctness: 65.146580)
# Epoch 21: (Cost: 0.688490, Correctness: 65.146580)
# Epoch 22: (Cost: 0.688159, Correctness: 65.146580)
# Epoch 23: (Cost: 0.687831, Correctness: 65.146580)
# Epoch 24: (Cost: 0.687506, Correctness: 65.146580)
# Epoch 25: (Cost: 0.687185, Correctness: 65.146580)
# Epoch 26: (Cost: 0.686867, Correctness: 65.146580)
# Epoch 27: (Cost: 0.686552, Correctness: 65.146580)
# Epoch 28: (Cost: 0.686240, Correctness: 65.146580)
# Epoch 29: (Cost: 0.685931, Correctness: 65.146580)
# Epoch 30: (Cost: 0.685625, Correctness: 65.146580)
# Epoch 31: (Cost: 0.685323, Correctness: 65.146580)
# Epoch 32: (Cost: 0.685023, Correctness: 65.146580)
# Epoch 33: (Cost: 0.684726, Correctness: 65.146580)
# Epoch 34: (Cost: 0.684432, Correctness: 65.146580)
# Epoch 35: (Cost: 0.684142, Correctness: 65.146580)
# Epoch 36: (Cost: 0.683854, Correctness: 65.146580)
# Epoch 37: (Cost: 0.683568, Correctness: 65.146580)
# Epoch 38: (Cost: 0.683286, Correctness: 65.146580)
# Epoch 39: (Cost: 0.683007, Correctness: 65.146580)
# Epoch 40: (Cost: 0.682730, Correctness: 65.146580)
# Epoch 41: (Cost: 0.682456, Correctness: 65.146580)
# Epoch 42: (Cost: 0.682184, Correctness: 65.146580)
# Epoch 43: (Cost: 0.681916, Correctness: 65.146580)
# Epoch 44: (Cost: 0.681650, Correctness: 65.146580)
# Epoch 45: (Cost: 0.681386, Correctness: 65.146580)
# Epoch 46: (Cost: 0.681125, Correctness: 65.146580)
# Epoch 47: (Cost: 0.680867, Correctness: 65.146580)
# Epoch 48: (Cost: 0.680611, Correctness: 65.146580)
# Epoch 49: (Cost: 0.680358, Correctness: 65.146580)
# Epoch 50: (Cost: 0.680107, Correctness: 65.146580)
# Epoch 51: (Cost: 0.679859, Correctness: 65.146580)
# Epoch 52: (Cost: 0.679613, Correctness: 65.146580)
# Epoch 53: (Cost: 0.679370, Correctness: 65.146580)
# Epoch 54: (Cost: 0.679129, Correctness: 65.146580)
# Epoch 55: (Cost: 0.678890, Correctness: 65.146580)
# Epoch 56: (Cost: 0.678653, Correctness: 65.146580)
# Epoch 57: (Cost: 0.678419, Correctness: 65.146580)
# Epoch 58: (Cost: 0.678188, Correctness: 65.146580)
# Epoch 59: (Cost: 0.677958, Correctness: 65.146580)
# Epoch 60: (Cost: 0.677731, Correctness: 65.146580)
# Epoch 61: (Cost: 0.677505, Correctness: 65.146580)
# Epoch 62: (Cost: 0.677282, Correctness: 65.146580)
# Epoch 63: (Cost: 0.677062, Correctness: 65.146580)
# Epoch 64: (Cost: 0.676843, Correctness: 65.146580)
# Epoch 65: (Cost: 0.676626, Correctness: 65.146580)
# Epoch 66: (Cost: 0.676412, Correctness: 65.146580)
# Epoch 67: (Cost: 0.676199, Correctness: 65.146580)
# Epoch 68: (Cost: 0.675989, Correctness: 65.146580)
# Epoch 69: (Cost: 0.675781, Correctness: 65.146580)
# Epoch 70: (Cost: 0.675574, Correctness: 65.146580)
# Epoch 71: (Cost: 0.675370, Correctness: 65.146580)
# Epoch 72: (Cost: 0.675168, Correctness: 65.146580)
# Epoch 73: (Cost: 0.674967, Correctness: 65.146580)
# Epoch 74: (Cost: 0.674768, Correctness: 65.146580)
# Epoch 75: (Cost: 0.674572, Correctness: 65.146580)
# Epoch 76: (Cost: 0.674377, Correctness: 65.146580)
# Epoch 77: (Cost: 0.674184, Correctness: 65.146580)
# Epoch 78: (Cost: 0.673993, Correctness: 65.146580)
# Epoch 79: (Cost: 0.673804, Correctness: 65.146580)
# Epoch 80: (Cost: 0.673616, Correctness: 65.146580)
# Epoch 81: (Cost: 0.673431, Correctness: 65.146580)
# Epoch 82: (Cost: 0.673247, Correctness: 65.146580)
# Epoch 83: (Cost: 0.673065, Correctness: 65.146580)
# Epoch 84: (Cost: 0.672884, Correctness: 65.146580)
# Epoch 85: (Cost: 0.672705, Correctness: 65.146580)
# Epoch 86: (Cost: 0.672528, Correctness: 65.146580)
# Epoch 87: (Cost: 0.672353, Correctness: 65.146580)
# Epoch 88: (Cost: 0.672179, Correctness: 65.146580)
# Epoch 89: (Cost: 0.672007, Correctness: 65.146580)
# Epoch 90: (Cost: 0.671837, Correctness: 65.146580)
# Epoch 91: (Cost: 0.671668, Correctness: 65.146580)
# Epoch 92: (Cost: 0.671500, Correctness: 65.146580)
# Epoch 93: (Cost: 0.671335, Correctness: 65.146580)
# Epoch 94: (Cost: 0.671170, Correctness: 65.146580)
# Epoch 95: (Cost: 0.671008, Correctness: 65.146580)
# Epoch 96: (Cost: 0.670847, Correctness: 65.146580)
# Epoch 97: (Cost: 0.670687, Correctness: 65.146580)
# Epoch 98: (Cost: 0.670529, Correctness: 65.146580)
# Epoch 99: (Cost: 0.670372, Correctness: 65.146580)
# Epoch 100: (Cost: 0.670217, Correctness: 65.146580)
# Epoch 101: (Cost: 0.670063, Correctness: 65.146580)
# Epoch 102: (Cost: 0.669911, Correctness: 65.146580)
# Epoch 103: (Cost: 0.669760, Correctness: 65.146580)
# Epoch 104: (Cost: 0.669610, Correctness: 65.146580)
# Epoch 105: (Cost: 0.669462, Correctness: 65.146580)
# Epoch 106: (Cost: 0.669315, Correctness: 65.146580)
# Epoch 107: (Cost: 0.669170, Correctness: 65.146580)
# Epoch 108: (Cost: 0.669026, Correctness: 65.146580)
# Epoch 109: (Cost: 0.668883, Correctness: 65.146580)
# Epoch 110: (Cost: 0.668741, Correctness: 65.146580)
# Epoch 111: (Cost: 0.668601, Correctness: 65.146580)
# Epoch 112: (Cost: 0.668462, Correctness: 65.146580)
# Epoch 113: (Cost: 0.668325, Correctness: 65.146580)
# Epoch 114: (Cost: 0.668188, Correctness: 65.146580)
# Epoch 115: (Cost: 0.668053, Correctness: 65.146580)
# Epoch 116: (Cost: 0.667919, Correctness: 65.146580)
# Epoch 117: (Cost: 0.667786, Correctness: 65.146580)
# Epoch 118: (Cost: 0.667655, Correctness: 65.146580)
# Epoch 119: (Cost: 0.667524, Correctness: 65.146580)
# Epoch 120: (Cost: 0.667395, Correctness: 65.146580)
# Epoch 121: (Cost: 0.667267, Correctness: 65.146580)
# Epoch 122: (Cost: 0.667140, Correctness: 65.146580)
# Epoch 123: (Cost: 0.667015, Correctness: 65.146580)
# Epoch 124: (Cost: 0.666890, Correctness: 65.146580)
# Epoch 125: (Cost: 0.666767, Correctness: 65.146580)
# Epoch 126: (Cost: 0.666644, Correctness: 65.146580)
# Epoch 127: (Cost: 0.666523, Correctness: 65.146580)
# Epoch 128: (Cost: 0.666403, Correctness: 65.146580)
# Epoch 129: (Cost: 0.666284, Correctness: 65.146580)
# Epoch 130: (Cost: 0.666166, Correctness: 65.146580)
# Epoch 131: (Cost: 0.666049, Correctness: 65.146580)
# Epoch 132: (Cost: 0.665933, Correctness: 65.146580)
# Epoch 133: (Cost: 0.665818, Correctness: 65.146580)
# Epoch 134: (Cost: 0.665704, Correctness: 65.146580)
# Epoch 135: (Cost: 0.665591, Correctness: 65.146580)
# Epoch 136: (Cost: 0.665479, Correctness: 65.146580)
# Epoch 137: (Cost: 0.665368, Correctness: 65.146580)
# Epoch 138: (Cost: 0.665258, Correctness: 65.146580)
# Epoch 139: (Cost: 0.665149, Correctness: 65.146580)
# Epoch 140: (Cost: 0.665041, Correctness: 65.146580)
# Epoch 141: (Cost: 0.664933, Correctness: 65.146580)
# Epoch 142: (Cost: 0.664827, Correctness: 65.146580)
# Epoch 143: (Cost: 0.664722, Correctness: 65.146580)
# Epoch 144: (Cost: 0.664617, Correctness: 65.146580)
# Epoch 145: (Cost: 0.664514, Correctness: 65.146580)
# Epoch 146: (Cost: 0.664411, Correctness: 65.146580)
# Epoch 147: (Cost: 0.664310, Correctness: 65.146580)
# Epoch 148: (Cost: 0.664209, Correctness: 65.146580)
# Epoch 149: (Cost: 0.664109, Correctness: 65.146580)
# Epoch 150: (Cost: 0.664010, Correctness: 65.146580)
# Epoch 151: (Cost: 0.663911, Correctness: 65.146580)
# Epoch 152: (Cost: 0.663814, Correctness: 65.146580)
# Epoch 153: (Cost: 0.663717, Correctness: 65.146580)
# Epoch 154: (Cost: 0.663622, Correctness: 65.146580)
# Epoch 155: (Cost: 0.663527, Correctness: 65.146580)
# Epoch 156: (Cost: 0.663432, Correctness: 65.146580)
# Epoch 157: (Cost: 0.663339, Correctness: 65.146580)
# Epoch 158: (Cost: 0.663246, Correctness: 65.146580)
# Epoch 159: (Cost: 0.663155, Correctness: 65.146580)
# Epoch 160: (Cost: 0.663064, Correctness: 65.146580)
# Epoch 161: (Cost: 0.662973, Correctness: 65.146580)
# Epoch 162: (Cost: 0.662884, Correctness: 65.146580)
# Epoch 163: (Cost: 0.662795, Correctness: 65.146580)
# Epoch 164: (Cost: 0.662707, Correctness: 65.146580)
# Epoch 165: (Cost: 0.662620, Correctness: 65.146580)
# Epoch 166: (Cost: 0.662533, Correctness: 65.146580)
# Epoch 167: (Cost: 0.662447, Correctness: 65.146580)
# Epoch 168: (Cost: 0.662362, Correctness: 65.146580)
# Epoch 169: (Cost: 0.662277, Correctness: 65.146580)
# Epoch 170: (Cost: 0.662194, Correctness: 65.146580)
# Epoch 171: (Cost: 0.662111, Correctness: 65.146580)
# Epoch 172: (Cost: 0.662028, Correctness: 65.146580)
# Epoch 173: (Cost: 0.661946, Correctness: 65.146580)
# Epoch 174: (Cost: 0.661865, Correctness: 65.146580)
# Epoch 175: (Cost: 0.661785, Correctness: 65.146580)
# Epoch 176: (Cost: 0.661705, Correctness: 65.146580)
# Epoch 177: (Cost: 0.661626, Correctness: 65.146580)
# Epoch 178: (Cost: 0.661547, Correctness: 65.146580)
# Epoch 179: (Cost: 0.661470, Correctness: 65.146580)
# Epoch 180: (Cost: 0.661392, Correctness: 65.146580)
# Epoch 181: (Cost: 0.661316, Correctness: 65.146580)
# Epoch 182: (Cost: 0.661240, Correctness: 65.146580)
# Epoch 183: (Cost: 0.661164, Correctness: 65.146580)
# Epoch 184: (Cost: 0.661090, Correctness: 65.146580)
# Epoch 185: (Cost: 0.661015, Correctness: 65.146580)
# Epoch 186: (Cost: 0.660942, Correctness: 65.146580)
# Epoch 187: (Cost: 0.660869, Correctness: 65.146580)
# Epoch 188: (Cost: 0.660796, Correctness: 65.146580)
# Epoch 189: (Cost: 0.660724, Correctness: 65.146580)
# Epoch 190: (Cost: 0.660653, Correctness: 65.146580)
# Epoch 191: (Cost: 0.660582, Correctness: 65.146580)
# Epoch 192: (Cost: 0.660512, Correctness: 65.146580)
# Epoch 193: (Cost: 0.660442, Correctness: 65.146580)
# Epoch 194: (Cost: 0.660373, Correctness: 65.146580)
# Epoch 195: (Cost: 0.660304, Correctness: 65.146580)
# Epoch 196: (Cost: 0.660236, Correctness: 65.146580)
# Epoch 197: (Cost: 0.660169, Correctness: 65.146580)
# Epoch 198: (Cost: 0.660102, Correctness: 65.146580)
# Epoch 199: (Cost: 0.660035, Correctness: 65.146580)
# Epoch 200: (Cost: 0.659969, Correctness: 65.146580)
# test accuracy(Correct/Total): 100.0/154
# test accuracy: 64.93506493506493 %

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.5, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695866, Correctness: 65.146580)
# Epoch 2: (Cost: 0.678118, Correctness: 65.146580)
# Epoch 3: (Cost: 0.668094, Correctness: 65.146580)
# Epoch 4: (Cost: 0.662232, Correctness: 65.146580)
# Epoch 5: (Cost: 0.658622, Correctness: 65.146580)
# Epoch 6: (Cost: 0.656240, Correctness: 65.146580)
# Epoch 7: (Cost: 0.654536, Correctness: 65.146580)
# Epoch 8: (Cost: 0.653209, Correctness: 65.146580)
# Epoch 9: (Cost: 0.652094, Correctness: 65.146580)
# Epoch 10: (Cost: 0.651100, Correctness: 65.146580)
# Epoch 11: (Cost: 0.650178, Correctness: 65.146580)
# Epoch 12: (Cost: 0.649299, Correctness: 65.146580)
# Epoch 13: (Cost: 0.648446, Correctness: 65.146580)
# Epoch 14: (Cost: 0.647611, Correctness: 65.146580)
# Epoch 15: (Cost: 0.646789, Correctness: 65.146580)
# Epoch 16: (Cost: 0.645977, Correctness: 65.146580)
# Epoch 17: (Cost: 0.645173, Correctness: 65.146580)
# Epoch 18: (Cost: 0.644376, Correctness: 65.146580)
# Epoch 19: (Cost: 0.643586, Correctness: 65.146580)
# Epoch 20: (Cost: 0.642802, Correctness: 65.146580)
# Epoch 21: (Cost: 0.642025, Correctness: 65.146580)
# Epoch 22: (Cost: 0.641253, Correctness: 65.146580)
# Epoch 23: (Cost: 0.640487, Correctness: 65.146580)
# Epoch 24: (Cost: 0.639728, Correctness: 65.146580)
# Epoch 25: (Cost: 0.638973, Correctness: 65.146580)
# Epoch 26: (Cost: 0.638225, Correctness: 65.146580)
# Epoch 27: (Cost: 0.637482, Correctness: 65.146580)
# Epoch 28: (Cost: 0.636745, Correctness: 65.146580)
# Epoch 29: (Cost: 0.636013, Correctness: 65.146580)
# Epoch 30: (Cost: 0.635287, Correctness: 65.146580)
# Epoch 31: (Cost: 0.634566, Correctness: 65.146580)
# Epoch 32: (Cost: 0.633850, Correctness: 65.146580)
# Epoch 33: (Cost: 0.633140, Correctness: 65.146580)
# Epoch 34: (Cost: 0.632435, Correctness: 65.146580)
# Epoch 35: (Cost: 0.631735, Correctness: 65.146580)
# Epoch 36: (Cost: 0.631040, Correctness: 65.146580)
# Epoch 37: (Cost: 0.630351, Correctness: 65.146580)
# Epoch 38: (Cost: 0.629666, Correctness: 65.146580)
# Epoch 39: (Cost: 0.628987, Correctness: 65.146580)
# Epoch 40: (Cost: 0.628312, Correctness: 65.146580)
# Epoch 41: (Cost: 0.627642, Correctness: 65.146580)
# Epoch 42: (Cost: 0.626978, Correctness: 65.146580)
# Epoch 43: (Cost: 0.626318, Correctness: 65.146580)
# Epoch 44: (Cost: 0.625662, Correctness: 65.146580)
# Epoch 45: (Cost: 0.625012, Correctness: 65.146580)
# Epoch 46: (Cost: 0.624366, Correctness: 65.146580)
# Epoch 47: (Cost: 0.623725, Correctness: 65.146580)
# Epoch 48: (Cost: 0.623089, Correctness: 65.146580)
# Epoch 49: (Cost: 0.622457, Correctness: 65.146580)
# Epoch 50: (Cost: 0.621829, Correctness: 65.146580)
# Epoch 51: (Cost: 0.621206, Correctness: 65.146580)
# Epoch 52: (Cost: 0.620588, Correctness: 65.146580)
# Epoch 53: (Cost: 0.619974, Correctness: 65.146580)
# Epoch 54: (Cost: 0.619364, Correctness: 65.146580)
# Epoch 55: (Cost: 0.618759, Correctness: 65.146580)
# Epoch 56: (Cost: 0.618157, Correctness: 65.146580)
# Epoch 57: (Cost: 0.617560, Correctness: 65.146580)
# Epoch 58: (Cost: 0.616968, Correctness: 65.146580)
# Epoch 59: (Cost: 0.616379, Correctness: 65.146580)
# Epoch 60: (Cost: 0.615795, Correctness: 65.146580)
# Epoch 61: (Cost: 0.615214, Correctness: 65.146580)
# Epoch 62: (Cost: 0.614638, Correctness: 65.146580)
# Epoch 63: (Cost: 0.614066, Correctness: 65.146580)
# Epoch 64: (Cost: 0.613497, Correctness: 65.146580)
# Epoch 65: (Cost: 0.612933, Correctness: 65.146580)
# Epoch 66: (Cost: 0.612373, Correctness: 65.309446)
# Epoch 67: (Cost: 0.611816, Correctness: 65.309446)
# Epoch 68: (Cost: 0.611263, Correctness: 65.309446)
# Epoch 69: (Cost: 0.610714, Correctness: 65.309446)
# Epoch 70: (Cost: 0.610169, Correctness: 65.309446)
# Epoch 71: (Cost: 0.609627, Correctness: 65.309446)
# Epoch 72: (Cost: 0.609090, Correctness: 65.309446)
# Epoch 73: (Cost: 0.608555, Correctness: 65.472313)
# Epoch 74: (Cost: 0.608025, Correctness: 65.472313)
# Epoch 75: (Cost: 0.607498, Correctness: 65.472313)
# Epoch 76: (Cost: 0.606975, Correctness: 65.309446)
# Epoch 77: (Cost: 0.606455, Correctness: 65.309446)
# Epoch 78: (Cost: 0.605938, Correctness: 65.309446)
# Epoch 79: (Cost: 0.605425, Correctness: 65.309446)
# Epoch 80: (Cost: 0.604916, Correctness: 65.309446)
# Epoch 81: (Cost: 0.604410, Correctness: 65.309446)
# Epoch 82: (Cost: 0.603907, Correctness: 65.472313)
# Epoch 83: (Cost: 0.603408, Correctness: 65.472313)
# Epoch 84: (Cost: 0.602912, Correctness: 65.798046)
# Epoch 85: (Cost: 0.602419, Correctness: 65.798046)
# Epoch 86: (Cost: 0.601929, Correctness: 65.798046)
# Epoch 87: (Cost: 0.601443, Correctness: 65.798046)
# Epoch 88: (Cost: 0.600960, Correctness: 65.798046)
# Epoch 89: (Cost: 0.600480, Correctness: 65.798046)
# Epoch 90: (Cost: 0.600003, Correctness: 65.960912)
# Epoch 91: (Cost: 0.599530, Correctness: 65.960912)
# Epoch 92: (Cost: 0.599059, Correctness: 65.960912)
# Epoch 93: (Cost: 0.598591, Correctness: 66.123779)
# Epoch 94: (Cost: 0.598127, Correctness: 66.286645)
# Epoch 95: (Cost: 0.597665, Correctness: 66.449511)
# Epoch 96: (Cost: 0.597207, Correctness: 66.449511)
# Epoch 97: (Cost: 0.596751, Correctness: 66.612378)
# Epoch 98: (Cost: 0.596299, Correctness: 66.775244)
# Epoch 99: (Cost: 0.595849, Correctness: 66.612378)
# Epoch 100: (Cost: 0.595402, Correctness: 66.612378)
# Epoch 101: (Cost: 0.594958, Correctness: 66.612378)
# Epoch 102: (Cost: 0.594517, Correctness: 66.286645)
# Epoch 103: (Cost: 0.594078, Correctness: 66.286645)
# Epoch 104: (Cost: 0.593642, Correctness: 66.449511)
# Epoch 105: (Cost: 0.593209, Correctness: 66.449511)
# Epoch 106: (Cost: 0.592779, Correctness: 66.612378)
# Epoch 107: (Cost: 0.592352, Correctness: 66.612378)
# Epoch 108: (Cost: 0.591927, Correctness: 66.612378)
# Epoch 109: (Cost: 0.591505, Correctness: 66.775244)
# Epoch 110: (Cost: 0.591085, Correctness: 66.938111)
# Epoch 111: (Cost: 0.590668, Correctness: 66.938111)
# Epoch 112: (Cost: 0.590254, Correctness: 66.938111)
# Epoch 113: (Cost: 0.589842, Correctness: 66.938111)
# Epoch 114: (Cost: 0.589433, Correctness: 66.938111)
# Epoch 115: (Cost: 0.589026, Correctness: 66.449511)
# Epoch 116: (Cost: 0.588622, Correctness: 66.449511)
# Epoch 117: (Cost: 0.588220, Correctness: 66.612378)
# Epoch 118: (Cost: 0.587821, Correctness: 66.612378)
# Epoch 119: (Cost: 0.587424, Correctness: 66.612378)
# Epoch 120: (Cost: 0.587029, Correctness: 66.612378)
# Epoch 121: (Cost: 0.586637, Correctness: 66.775244)
# Epoch 122: (Cost: 0.586248, Correctness: 66.938111)
# Epoch 123: (Cost: 0.585860, Correctness: 67.263844)
# Epoch 124: (Cost: 0.585475, Correctness: 67.100977)
# Epoch 125: (Cost: 0.585093, Correctness: 66.938111)
# Epoch 126: (Cost: 0.584712, Correctness: 66.938111)
# Epoch 127: (Cost: 0.584334, Correctness: 66.938111)
# Epoch 128: (Cost: 0.583958, Correctness: 67.263844)
# Epoch 129: (Cost: 0.583585, Correctness: 67.589577)
# Epoch 130: (Cost: 0.583213, Correctness: 67.915309)
# Epoch 131: (Cost: 0.582844, Correctness: 68.078176)
# Epoch 132: (Cost: 0.582477, Correctness: 68.078176)
# Epoch 133: (Cost: 0.582112, Correctness: 68.241042)
# Epoch 134: (Cost: 0.581749, Correctness: 68.078176)
# Epoch 135: (Cost: 0.581389, Correctness: 68.241042)
# Epoch 136: (Cost: 0.581030, Correctness: 68.241042)
# Epoch 137: (Cost: 0.580674, Correctness: 68.241042)
# Epoch 138: (Cost: 0.580320, Correctness: 68.241042)
# Epoch 139: (Cost: 0.579967, Correctness: 68.403909)
# Epoch 140: (Cost: 0.579617, Correctness: 68.566775)
# Epoch 141: (Cost: 0.579269, Correctness: 68.566775)
# Epoch 142: (Cost: 0.578923, Correctness: 68.566775)
# Epoch 143: (Cost: 0.578578, Correctness: 68.566775)
# Epoch 144: (Cost: 0.578236, Correctness: 68.729642)
# Epoch 145: (Cost: 0.577896, Correctness: 68.729642)
# Epoch 146: (Cost: 0.577558, Correctness: 68.729642)
# Epoch 147: (Cost: 0.577221, Correctness: 69.218241)
# Epoch 148: (Cost: 0.576887, Correctness: 69.218241)
# Epoch 149: (Cost: 0.576554, Correctness: 69.218241)
# Epoch 150: (Cost: 0.576223, Correctness: 69.218241)
# Epoch 151: (Cost: 0.575895, Correctness: 68.892508)
# Epoch 152: (Cost: 0.575568, Correctness: 68.892508)
# Epoch 153: (Cost: 0.575242, Correctness: 69.218241)
# Epoch 154: (Cost: 0.574919, Correctness: 69.218241)
# Epoch 155: (Cost: 0.574597, Correctness: 69.218241)
# Epoch 156: (Cost: 0.574278, Correctness: 69.543974)
# Epoch 157: (Cost: 0.573960, Correctness: 69.543974)
# Epoch 158: (Cost: 0.573644, Correctness: 69.381107)
# Epoch 159: (Cost: 0.573329, Correctness: 69.381107)
# Epoch 160: (Cost: 0.573016, Correctness: 69.381107)
# Epoch 161: (Cost: 0.572705, Correctness: 69.381107)
# Epoch 162: (Cost: 0.572396, Correctness: 69.381107)
# Epoch 163: (Cost: 0.572089, Correctness: 69.543974)
# Epoch 164: (Cost: 0.571783, Correctness: 69.706840)
# Epoch 165: (Cost: 0.571478, Correctness: 69.706840)
# Epoch 166: (Cost: 0.571176, Correctness: 69.706840)
# Epoch 167: (Cost: 0.570875, Correctness: 69.706840)
# Epoch 168: (Cost: 0.570576, Correctness: 69.706840)
# Epoch 169: (Cost: 0.570278, Correctness: 69.706840)
# Epoch 170: (Cost: 0.569982, Correctness: 69.869707)
# Epoch 171: (Cost: 0.569687, Correctness: 69.869707)
# Epoch 172: (Cost: 0.569394, Correctness: 69.869707)
# Epoch 173: (Cost: 0.569103, Correctness: 69.869707)
# Epoch 174: (Cost: 0.568813, Correctness: 69.869707)
# Epoch 175: (Cost: 0.568525, Correctness: 69.869707)
# Epoch 176: (Cost: 0.568238, Correctness: 69.869707)
# Epoch 177: (Cost: 0.567953, Correctness: 69.706840)
# Epoch 178: (Cost: 0.567669, Correctness: 69.706840)
# Epoch 179: (Cost: 0.567387, Correctness: 69.869707)
# Epoch 180: (Cost: 0.567107, Correctness: 69.869707)
# Epoch 181: (Cost: 0.566827, Correctness: 69.869707)
# Epoch 182: (Cost: 0.566550, Correctness: 69.869707)
# Epoch 183: (Cost: 0.566273, Correctness: 69.869707)
# Epoch 184: (Cost: 0.565998, Correctness: 69.869707)
# Epoch 185: (Cost: 0.565725, Correctness: 69.869707)
# Epoch 186: (Cost: 0.565453, Correctness: 69.869707)
# Epoch 187: (Cost: 0.565182, Correctness: 69.869707)
# Epoch 188: (Cost: 0.564913, Correctness: 70.032573)
# Epoch 189: (Cost: 0.564645, Correctness: 70.032573)
# Epoch 190: (Cost: 0.564379, Correctness: 70.195440)
# Epoch 191: (Cost: 0.564114, Correctness: 70.195440)
# Epoch 192: (Cost: 0.563850, Correctness: 70.521173)
# Epoch 193: (Cost: 0.563588, Correctness: 70.521173)
# Epoch 194: (Cost: 0.563327, Correctness: 70.846906)
# Epoch 195: (Cost: 0.563067, Correctness: 71.009772)
# Epoch 196: (Cost: 0.562808, Correctness: 71.009772)
# Epoch 197: (Cost: 0.562551, Correctness: 71.009772)
# Epoch 198: (Cost: 0.562296, Correctness: 71.009772)
# Epoch 199: (Cost: 0.562041, Correctness: 71.009772)
# Epoch 200: (Cost: 0.561788, Correctness: 71.172638)
# test accuracy(Correct/Total): 112.0/154
# test accuracy: 72.72727272727273 %

# %%
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 2, num_iterations = 200)
# Out:
# Epoch 1: (Cost: 0.695866, Correctness: 65.146580)
# Epoch 2: (Cost: 0.655224, Correctness: 65.146580)
# Epoch 3: (Cost: 0.651715, Correctness: 65.146580)
# Epoch 4: (Cost: 0.648354, Correctness: 65.146580)
# Epoch 5: (Cost: 0.645096, Correctness: 65.146580)
# Epoch 6: (Cost: 0.641936, Correctness: 65.146580)
# Epoch 7: (Cost: 0.638871, Correctness: 65.146580)
# Epoch 8: (Cost: 0.635898, Correctness: 65.146580)
# Epoch 9: (Cost: 0.633013, Correctness: 65.146580)
# Epoch 10: (Cost: 0.630213, Correctness: 65.146580)
# Epoch 11: (Cost: 0.627495, Correctness: 65.146580)
# Epoch 12: (Cost: 0.624856, Correctness: 65.146580)
# Epoch 13: (Cost: 0.622292, Correctness: 65.146580)
# Epoch 14: (Cost: 0.619802, Correctness: 65.146580)
# Epoch 15: (Cost: 0.617382, Correctness: 65.146580)
# Epoch 16: (Cost: 0.615030, Correctness: 65.309446)
# Epoch 17: (Cost: 0.612743, Correctness: 65.309446)
# Epoch 18: (Cost: 0.610519, Correctness: 65.309446)
# Epoch 19: (Cost: 0.608356, Correctness: 65.309446)
# Epoch 20: (Cost: 0.606251, Correctness: 65.635179)
# Epoch 21: (Cost: 0.604203, Correctness: 65.798046)
# Epoch 22: (Cost: 0.602209, Correctness: 65.960912)
# Epoch 23: (Cost: 0.600268, Correctness: 66.449511)
# Epoch 24: (Cost: 0.598377, Correctness: 66.612378)
# Epoch 25: (Cost: 0.596535, Correctness: 66.449511)
# Epoch 26: (Cost: 0.594740, Correctness: 66.612378)
# Epoch 27: (Cost: 0.592990, Correctness: 66.938111)
# Epoch 28: (Cost: 0.591284, Correctness: 66.449511)
# Epoch 29: (Cost: 0.589621, Correctness: 66.612378)
# Epoch 30: (Cost: 0.587998, Correctness: 67.100977)
# Epoch 31: (Cost: 0.586415, Correctness: 67.100977)
# Epoch 32: (Cost: 0.584870, Correctness: 68.078176)
# Epoch 33: (Cost: 0.583362, Correctness: 68.241042)
# Epoch 34: (Cost: 0.581890, Correctness: 68.566775)
# Epoch 35: (Cost: 0.580452, Correctness: 68.729642)
# Epoch 36: (Cost: 0.579047, Correctness: 69.218241)
# Epoch 37: (Cost: 0.577675, Correctness: 68.892508)
# Epoch 38: (Cost: 0.576334, Correctness: 69.543974)
# Epoch 39: (Cost: 0.575023, Correctness: 69.218241)
# Epoch 40: (Cost: 0.573741, Correctness: 69.706840)
# Epoch 41: (Cost: 0.572487, Correctness: 69.706840)
# Epoch 42: (Cost: 0.571261, Correctness: 69.869707)
# Epoch 43: (Cost: 0.570062, Correctness: 69.706840)
# Epoch 44: (Cost: 0.568888, Correctness: 69.869707)
# Epoch 45: (Cost: 0.567740, Correctness: 69.869707)
# Epoch 46: (Cost: 0.566615, Correctness: 70.032573)
# Epoch 47: (Cost: 0.565514, Correctness: 70.521173)
# Epoch 48: (Cost: 0.564436, Correctness: 71.009772)
# Epoch 49: (Cost: 0.563379, Correctness: 71.172638)
# Epoch 50: (Cost: 0.562345, Correctness: 71.498371)
# Epoch 51: (Cost: 0.561331, Correctness: 72.149837)
# Epoch 52: (Cost: 0.560337, Correctness: 72.312704)
# Epoch 53: (Cost: 0.559363, Correctness: 72.312704)
# Epoch 54: (Cost: 0.558408, Correctness: 72.149837)
# Epoch 55: (Cost: 0.557471, Correctness: 72.475570)
# Epoch 56: (Cost: 0.556553, Correctness: 72.475570)
# Epoch 57: (Cost: 0.555652, Correctness: 72.638436)
# Epoch 58: (Cost: 0.554768, Correctness: 72.638436)
# Epoch 59: (Cost: 0.553900, Correctness: 72.964169)
# Epoch 60: (Cost: 0.553049, Correctness: 72.801303)
# Epoch 61: (Cost: 0.552213, Correctness: 72.801303)
# Epoch 62: (Cost: 0.551393, Correctness: 72.801303)
# Epoch 63: (Cost: 0.550587, Correctness: 73.127036)
# Epoch 64: (Cost: 0.549796, Correctness: 73.289902)
# Epoch 65: (Cost: 0.549019, Correctness: 72.964169)
# Epoch 66: (Cost: 0.548256, Correctness: 73.127036)
# Epoch 67: (Cost: 0.547506, Correctness: 73.127036)
# Epoch 68: (Cost: 0.546769, Correctness: 73.127036)
# Epoch 69: (Cost: 0.546044, Correctness: 73.127036)
# Epoch 70: (Cost: 0.545332, Correctness: 73.127036)
# Epoch 71: (Cost: 0.544633, Correctness: 73.289902)
# Epoch 72: (Cost: 0.543945, Correctness: 73.452769)
# Epoch 73: (Cost: 0.543268, Correctness: 73.452769)
# Epoch 74: (Cost: 0.542603, Correctness: 73.615635)
# Epoch 75: (Cost: 0.541948, Correctness: 73.778502)
# Epoch 76: (Cost: 0.541304, Correctness: 73.778502)
# Epoch 77: (Cost: 0.540671, Correctness: 73.778502)
# Epoch 78: (Cost: 0.540048, Correctness: 73.941368)
# Epoch 79: (Cost: 0.539434, Correctness: 73.941368)
# Epoch 80: (Cost: 0.538831, Correctness: 73.941368)
# Epoch 81: (Cost: 0.538237, Correctness: 73.941368)
# Epoch 82: (Cost: 0.537652, Correctness: 73.778502)
# Epoch 83: (Cost: 0.537076, Correctness: 73.778502)
# Epoch 84: (Cost: 0.536509, Correctness: 73.778502)
# Epoch 85: (Cost: 0.535951, Correctness: 73.778502)
# Epoch 86: (Cost: 0.535401, Correctness: 73.452769)
# Epoch 87: (Cost: 0.534859, Correctness: 73.615635)
# Epoch 88: (Cost: 0.534326, Correctness: 73.615635)
# Epoch 89: (Cost: 0.533800, Correctness: 73.615635)
# Epoch 90: (Cost: 0.533282, Correctness: 73.615635)
# Epoch 91: (Cost: 0.532772, Correctness: 73.615635)
# Epoch 92: (Cost: 0.532269, Correctness: 73.615635)
# Epoch 93: (Cost: 0.531773, Correctness: 73.615635)
# Epoch 94: (Cost: 0.531285, Correctness: 73.778502)
# Epoch 95: (Cost: 0.530803, Correctness: 73.941368)
# Epoch 96: (Cost: 0.530328, Correctness: 74.104235)
# Epoch 97: (Cost: 0.529860, Correctness: 74.104235)
# Epoch 98: (Cost: 0.529399, Correctness: 74.104235)
# Epoch 99: (Cost: 0.528943, Correctness: 74.104235)
# Epoch 100: (Cost: 0.528494, Correctness: 73.941368)
# Epoch 101: (Cost: 0.528052, Correctness: 74.104235)
# Epoch 102: (Cost: 0.527615, Correctness: 74.104235)
# Epoch 103: (Cost: 0.527184, Correctness: 74.104235)
# Epoch 104: (Cost: 0.526759, Correctness: 74.429967)
# Epoch 105: (Cost: 0.526339, Correctness: 74.429967)
# Epoch 106: (Cost: 0.525925, Correctness: 74.429967)
# Epoch 107: (Cost: 0.525517, Correctness: 74.429967)
# Epoch 108: (Cost: 0.525114, Correctness: 74.429967)
# Epoch 109: (Cost: 0.524716, Correctness: 74.755700)
# Epoch 110: (Cost: 0.524323, Correctness: 75.244300)
# Epoch 111: (Cost: 0.523936, Correctness: 75.244300)
# Epoch 112: (Cost: 0.523553, Correctness: 75.407166)
# Epoch 113: (Cost: 0.523175, Correctness: 75.407166)
# Epoch 114: (Cost: 0.522802, Correctness: 75.407166)
# Epoch 115: (Cost: 0.522434, Correctness: 75.570033)
# Epoch 116: (Cost: 0.522070, Correctness: 75.570033)
# Epoch 117: (Cost: 0.521711, Correctness: 75.570033)
# Epoch 118: (Cost: 0.521356, Correctness: 75.570033)
# Epoch 119: (Cost: 0.521005, Correctness: 75.570033)
# Epoch 120: (Cost: 0.520659, Correctness: 75.570033)
# Epoch 121: (Cost: 0.520317, Correctness: 75.407166)
# Epoch 122: (Cost: 0.519979, Correctness: 75.407166)
# Epoch 123: (Cost: 0.519645, Correctness: 75.570033)
# Epoch 124: (Cost: 0.519315, Correctness: 75.570033)
# Epoch 125: (Cost: 0.518989, Correctness: 75.570033)
# Epoch 126: (Cost: 0.518667, Correctness: 75.570033)
# Epoch 127: (Cost: 0.518349, Correctness: 75.570033)
# Epoch 128: (Cost: 0.518035, Correctness: 75.570033)
# Epoch 129: (Cost: 0.517724, Correctness: 75.732899)
# Epoch 130: (Cost: 0.517416, Correctness: 75.732899)
# Epoch 131: (Cost: 0.517112, Correctness: 75.895765)
# Epoch 132: (Cost: 0.516812, Correctness: 75.895765)
# Epoch 133: (Cost: 0.516515, Correctness: 76.058632)
# Epoch 134: (Cost: 0.516222, Correctness: 75.895765)
# Epoch 135: (Cost: 0.515931, Correctness: 75.895765)
# Epoch 136: (Cost: 0.515644, Correctness: 75.895765)
# Epoch 137: (Cost: 0.515361, Correctness: 75.895765)
# Epoch 138: (Cost: 0.515080, Correctness: 75.895765)
# Epoch 139: (Cost: 0.514802, Correctness: 75.732899)
# Epoch 140: (Cost: 0.514528, Correctness: 75.895765)
# Epoch 141: (Cost: 0.514256, Correctness: 75.895765)
# Epoch 142: (Cost: 0.513988, Correctness: 75.895765)
# Epoch 143: (Cost: 0.513722, Correctness: 75.895765)
# Epoch 144: (Cost: 0.513459, Correctness: 75.895765)
# Epoch 145: (Cost: 0.513199, Correctness: 75.895765)
# Epoch 146: (Cost: 0.512942, Correctness: 75.895765)
# Epoch 147: (Cost: 0.512688, Correctness: 75.895765)
# Epoch 148: (Cost: 0.512436, Correctness: 75.895765)
# Epoch 149: (Cost: 0.512187, Correctness: 76.058632)
# Epoch 150: (Cost: 0.511940, Correctness: 76.058632)
# Epoch 151: (Cost: 0.511696, Correctness: 76.058632)
# Epoch 152: (Cost: 0.511455, Correctness: 76.221498)
# Epoch 153: (Cost: 0.511216, Correctness: 76.221498)
# Epoch 154: (Cost: 0.510980, Correctness: 76.221498)
# Epoch 155: (Cost: 0.510746, Correctness: 76.384365)
# Epoch 156: (Cost: 0.510514, Correctness: 76.384365)
# Epoch 157: (Cost: 0.510285, Correctness: 76.384365)
# Epoch 158: (Cost: 0.510058, Correctness: 76.384365)
# Epoch 159: (Cost: 0.509833, Correctness: 76.384365)
# Epoch 160: (Cost: 0.509610, Correctness: 76.384365)
# Epoch 161: (Cost: 0.509390, Correctness: 76.384365)
# Epoch 162: (Cost: 0.509172, Correctness: 76.384365)
# Epoch 163: (Cost: 0.508956, Correctness: 76.384365)
# Epoch 164: (Cost: 0.508742, Correctness: 76.384365)
# Epoch 165: (Cost: 0.508531, Correctness: 76.384365)
# Epoch 166: (Cost: 0.508321, Correctness: 76.384365)
# Epoch 167: (Cost: 0.508113, Correctness: 76.384365)
# Epoch 168: (Cost: 0.507908, Correctness: 76.384365)
# Epoch 169: (Cost: 0.507704, Correctness: 76.221498)
# Epoch 170: (Cost: 0.507503, Correctness: 76.221498)
# Epoch 171: (Cost: 0.507303, Correctness: 76.384365)
# Epoch 172: (Cost: 0.507105, Correctness: 76.547231)
# Epoch 173: (Cost: 0.506909, Correctness: 76.710098)
# Epoch 174: (Cost: 0.506715, Correctness: 76.872964)
# Epoch 175: (Cost: 0.506523, Correctness: 76.872964)
# Epoch 176: (Cost: 0.506332, Correctness: 76.872964)
# Epoch 177: (Cost: 0.506144, Correctness: 76.872964)
# Epoch 178: (Cost: 0.505957, Correctness: 76.872964)
# Epoch 179: (Cost: 0.505772, Correctness: 76.872964)
# Epoch 180: (Cost: 0.505588, Correctness: 76.872964)
# Epoch 181: (Cost: 0.505406, Correctness: 76.872964)
# Epoch 182: (Cost: 0.505226, Correctness: 76.872964)
# Epoch 183: (Cost: 0.505048, Correctness: 76.710098)
# Epoch 184: (Cost: 0.504871, Correctness: 76.710098)
# Epoch 185: (Cost: 0.504695, Correctness: 76.710098)
# Epoch 186: (Cost: 0.504522, Correctness: 76.710098)
# Epoch 187: (Cost: 0.504350, Correctness: 76.710098)
# Epoch 188: (Cost: 0.504179, Correctness: 76.710098)
# Epoch 189: (Cost: 0.504010, Correctness: 76.547231)
# Epoch 190: (Cost: 0.503843, Correctness: 76.547231)
# Epoch 191: (Cost: 0.503676, Correctness: 76.547231)
# Epoch 192: (Cost: 0.503512, Correctness: 76.710098)
# Epoch 193: (Cost: 0.503349, Correctness: 76.710098)
# Epoch 194: (Cost: 0.503187, Correctness: 76.710098)
# Epoch 195: (Cost: 0.503027, Correctness: 76.710098)
# Epoch 196: (Cost: 0.502868, Correctness: 76.710098)
# Epoch 197: (Cost: 0.502710, Correctness: 76.710098)
# Epoch 198: (Cost: 0.502554, Correctness: 76.710098)
# Epoch 199: (Cost: 0.502399, Correctness: 76.710098)
# Epoch 200: (Cost: 0.502246, Correctness: 76.710098)
# test accuracy(Correct/Total): 118.0/154
# test accuracy: 76.62337662337663 %
